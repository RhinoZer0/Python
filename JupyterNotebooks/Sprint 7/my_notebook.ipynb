# %%
print("Hello world")
# Out:
# Hello world

# %%
import os

cpu_num = os.cpu_count()
print(f"Mi computadora tiene {cpu_num} núcleos de CPU")
# Out:
# Mi computadora tiene 24 núcleos de CPU

# %%
# !python CPU.py
# Out:
# Mi computadora tiene 24 núcleos de CPU

# %%
# !echo Hello World
# Out:
# Hello World

# %% [markdown]
# ## Texto e imágenes en un cuaderno
# ---
# En Jupyter Notebook puedes mezclar:
# * código;
# * texto;
# * imágenes.

# %% [markdown]
# ![Screenshot 2024-11-07 153241.png](attachment:594209f5-365d-41db-8ac5-22ed88fb02e6.png)

# %% [markdown]
# # Hola

# %% [markdown]
# ## Hola

# %% [markdown]
# ### Hola

# %% [markdown]
# #### Hola

# %% [markdown]
# ##### Hola

# %% [markdown]
# Hola

# %%
import sys
sys.version
# Out:
# '3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]'

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
import plotly
